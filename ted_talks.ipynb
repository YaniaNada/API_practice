# %% [markdown]
# <a href="https://colab.research.google.com/github/YaniaNada/API_practice/blob/main/ted_talks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd

# %%
url = "https://ted-talks-api.p.rapidapi.com/talks"

querystring = {"from_record_date":"2017-01-01","min_duration":"300","audio_lang":"en"}

headers = {
	"x-rapidapi-key": "b3ce68d4b6mshe0b838ef2c71dfap15fa17jsne7cb808d8728",
	"x-rapidapi-host": "ted-talks-api.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

data = response.json()
print(data)
# Out:
# {'get': 'talks', 'parameters': [{'name': 'audio_lang', 'value': 'en'}, {'name': 'from_record_date', 'value': '2017-01-01'}, {'name': 'min_duration', 'value': '300'}], 'errors': [], 'result': {'num_results': 737, 'results': [{'id': 15555, 'url': 'https://www.ted.com/talks/emily_levine_how_i_made_friends_with_reality', 'title': 'How I made friends with reality', 'description': 'With her signature wit and wisdom, Emily Levine meets her ultimate challenge as a comedian/philosopher: she makes dying funny. In this personal talk, she takes us on her journey to make friends with reality -- and peace with death. Life is an enormous gift, Levine says: "You enrich it as best you can, and then you give it back."', 'audio_language': 'en', 'event': 'TED2018', 'publish_date': '2018-05-23T00:00:00Z', 'record_date': '2018-04-10T00:00:00Z', 'duration_in_seconds': 932, 'thumbnail_url': 'https://pi.tedcdn.com/r/talkstar-photos.s3.amazonaws.com/uploads/8ccd7c0f-f812-4213-9303-7d7bb1cde872/EmilyLevine_201
# ...

# %%
# Out:
# dict_items([('get', 'talks'), ('parameters', [{'name': 'audio_lang', 'value': 'en'}, {'name': 'from_record_date', 'value': '2017-01-01'}, {'name': 'min_duration', 'value': '300'}]), ('errors', []), ('result', {'num_results': 737, 'results': [{'id': 15555, 'url': 'https://www.ted.com/talks/emily_levine_how_i_made_friends_with_reality', 'title': 'How I made friends with reality', 'description': 'With her signature wit and wisdom, Emily Levine meets her ultimate challenge as a comedian/philosopher: she makes dying funny. In this personal talk, she takes us on her journey to make friends with reality -- and peace with death. Life is an enormous gift, Levine says: "You enrich it as best you can, and then you give it back."', 'audio_language': 'en', 'event': 'TED2018', 'publish_date': '2018-05-23T00:00:00Z', 'record_date': '2018-04-10T00:00:00Z', 'duration_in_seconds': 932, 'thumbnail_url': 'https://pi.tedcdn.com/r/talkstar-photos.s3.amazonaws.com/uploads/8ccd7c0f-f812-4213-9303-7d7bb1cde8
# ...

# %%
df= pd.DataFrame(data.items())
df.head()
# Out:
#             0                                                  1
# 0         get                                              talks
# 1  parameters  [{'name': 'audio_lang', 'value': 'en'}, {'name...
# 2      errors                                                 []
# 3      result  {'num_results': 737, 'results': [{'id': 15555,...

# %%
print(df[1][1])
# Out:
# [{'name': 'audio_lang', 'value': 'en'}, {'name': 'from_record_date', 'value': '2017-01-01'}, {'name': 'min_duration', 'value': '300'}]

# %%
print(df[1][3])
# Out:
# {'num_results': 737, 'results': [{'id': 15555, 'url': 'https://www.ted.com/talks/emily_levine_how_i_made_friends_with_reality', 'title': 'How I made friends with reality', 'description': 'With her signature wit and wisdom, Emily Levine meets her ultimate challenge as a comedian/philosopher: she makes dying funny. In this personal talk, she takes us on her journey to make friends with reality -- and peace with death. Life is an enormous gift, Levine says: "You enrich it as best you can, and then you give it back."', 'audio_language': 'en', 'event': 'TED2018', 'publish_date': '2018-05-23T00:00:00Z', 'record_date': '2018-04-10T00:00:00Z', 'duration_in_seconds': 932, 'thumbnail_url': 'https://pi.tedcdn.com/r/talkstar-photos.s3.amazonaws.com/uploads/8ccd7c0f-f812-4213-9303-7d7bb1cde872/EmilyLevine_2018-embed.jpg?quality=89&w=600', 'mp4_url': 'https://py.tedcdn.com/consus/projects/00/31/62/005/products/2018-emily-levine-005-fallback-8af7c1b06a50123286c7ba8a34457c18-1200k.mp4', 'embed_url':
# ...

# %%
df[1][3]['results']
# Out:
# [{'id': 15555,
#   'url': 'https://www.ted.com/talks/emily_levine_how_i_made_friends_with_reality',
#   'title': 'How I made friends with reality',
#   'description': 'With her signature wit and wisdom, Emily Levine meets her ultimate challenge as a comedian/philosopher: she makes dying funny. In this personal talk, she takes us on her journey to make friends with reality -- and peace with death. Life is an enormous gift, Levine says: "You enrich it as best you can, and then you give it back."',
#   'audio_language': 'en',
#   'event': 'TED2018',
#   'publish_date': '2018-05-23T00:00:00Z',
#   'record_date': '2018-04-10T00:00:00Z',
#   'duration_in_seconds': 932,
#   'thumbnail_url': 'https://pi.tedcdn.com/r/talkstar-photos.s3.amazonaws.com/uploads/8ccd7c0f-f812-4213-9303-7d7bb1cde872/EmilyLevine_2018-embed.jpg?quality=89&w=600',
#   'mp4_url': 'https://py.tedcdn.com/consus/projects/00/31/62/005/products/2018-emily-levine-005-fallback-8af7c1b06a50123286c7ba8a34457c18-1200k.mp4',
# ...

# %%
df_new = pd.DataFrame(df[1][3]['results'])
df_new.head()
# Out:
#       id                                                url  \
# 0  15555  https://www.ted.com/talks/emily_levine_how_i_m...
# 1  13720  https://www.ted.com/talks/michael_hendryx_the_...
# 2  16827  https://www.ted.com/talks/stephen_trzeciak_wan...
# 3  16820  https://www.ted.com/talks/kyle_quinn_what_marr...
# 4  15284  https://www.ted.com/talks/michael_rain_what_it...
#
#                                                title  \
# 0                    How I made friends with reality
# 1  The shocking danger of mountaintop removal -- ...
# 2         Want a happier life? Be more compassionate
# 3  What marrying an immigrant taught me about cul...
# 4       What it's like to be the child of immigrants
#
#                                          description audio_language  \
# 0  With her signature wit and wisdom, Emily Levin...             en
# 1  Research investigator Michael Hendryx studies ...             en
# 2  Stephen Trzeciak was at the top of his game as...             en
# ...
